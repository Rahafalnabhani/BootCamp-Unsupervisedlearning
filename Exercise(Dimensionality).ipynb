# %% [markdown]
# # Question :

# %%
# Download Boston Housing Dataset 
# Apply pca 2
# Scatter plot it

# %%
import pandas as pd
import numpy as np
from sklearn import datasets
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# %%
# Load the Boston Housing dataset by using the Link:
url = "https://archive.ics.uci.edu/ml/machine-learning-databases/housing/housing.data"
names = ['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX', 'PTRATIO', 'B', 'LSTAT', 'PRICE']
ex = pd.read_csv(url, delim_whitespace=True, names=names)

# %%
ex
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222.0
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273.0
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273.0
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273.0
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273.0
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273.0
#
#      PTRATIO       B  LSTAT  PRICE
# 0       15.3  396.90   4.98   24.0
# ...

# %%
#Standardize the features to have mean=0 and variance=1 :
scaler = StandardScaler()
x_scaled = scaler.fit_transform(ex)

# %%
# Apply PCA [] and fit the features selected :
pca = PCA(n_components=2)
pca.fit_transform(x_scaled)
# Out:
# array([[-2.08734387,  0.49281842],
#        [-1.37338152, -0.17090881],
#        [-2.37655336,  0.91406912],
#        ...,
#        [-0.36818965,  0.82315136],
#        [-0.26431734,  0.54000622],
#        [ 0.19523513, -0.55801653]])

# %%
# Apply PCA [] and fit the features selected :
pca = PCA(n_components=2)
x_pca=pca.fit_transform(x_scaled)

# %%
#visualizethe data
plt.figure(figsize=(8,6))
plt.scatter(x_pca[:,0],x_pca[:,1],c=ex.PRICE,alpha=0.5,cmap=plt.cm.get_cmap('GnBu',10))
plt.colorbar()
plt.xlabel('first principal component')
plt.ylabel('second principal component')
plt.title('PCA on Digits Dataset')
plt.show()
# Out:
# C:\Users\RAHAF HAMED ALNABHAN\AppData\Local\Temp\ipykernel_16044\1219341606.py:3: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   plt.scatter(x_pca[:,0],x_pca[:,1],c=ex.PRICE,alpha=0.5,cmap=plt.cm.get_cmap('GnBu',10))
