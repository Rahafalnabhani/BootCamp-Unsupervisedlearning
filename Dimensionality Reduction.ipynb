# %%
import pandas as pd
import numpy as np
from sklearn import datasets
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# %%
# Load digits dataset :
digits = datasets.load_digits()
x = digits.data

# %%
#Standardize the features to have mean=0 and variance=1 :
scaler = StandardScaler()
x_scaled = scaler.fit_transform(x)

# %%
# Apply PCA [] and fit the features selected :
pca = PCA(n_components=2)
pca.fit_transform(x_scaled)
# Out:
# array([[ 1.91419723, -0.9545126 ],
#        [ 0.58899165,  0.92464087],
#        [ 1.30206563, -0.31722253],
#        ...,
#        [ 1.02257461, -0.14794419],
#        [ 1.07604619, -0.38095263],
#        [-1.257733  , -2.22758749]])

# %%
# To show it as drawing :
plt.figure(figsize=[4,4])
plt.imshow(np.array(x[0]).reshape(8,8))
plt.show()

# %%
# Apply PCA [] and fit the features selected :
pca = PCA(n_components=2)
x_pca=pca.fit_transform(x_scaled)

# %%
#visualizethe data
plt.figure(figsize=(8,6))
plt.scatter(x_pca[:,0],x_pca[:,1],c=digits.target,alpha=0.5,cmap=plt.cm.get_cmap('GnBu',10))
plt.colorbar()
plt.xlabel('first principal component')
plt.ylabel('second principal component')
plt.title('PCA on Digits Dataset')
plt.show()
# Out:
# C:\Users\RAHAF HAMED ALNABHAN\AppData\Local\Temp\ipykernel_21644\2652059670.py:3: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   plt.scatter(x_pca[:,0],x_pca[:,1],c=digits.target,alpha=0.5,cmap=plt.cm.get_cmap('GnBu',10))

# %%
print('Explained Variance: ',pca.explained_variance_ratio_)
# Out:
# Explained Variance:  [0.12033916 0.09561054]

# %% [markdown]
# # Example 2 : Diabetes Dataset

# %%
# Load digits dataset :
diabetes = datasets.load_digits()
x = diabetes.data
