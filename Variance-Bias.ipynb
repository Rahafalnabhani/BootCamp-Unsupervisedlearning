# %%
# Notes :
#    1- Low variance , high Bias [underfitting]
#    2- High variance , low Bias [overfitting]
# MSE 
# The Train data is low and test data more [overfitting] The model not perfect ---> 1
# The model must be enough and not to much
# The model must not be overfit and underfit [السعه و higher ]

# %%
# Bias :
# The different between average predication and

# %%
# Variance :
# The different between the predication and the what how to be prdication [المفروض يكون ]  Big
# The performenace ---> if differnt between training and testing is high the model wronge
# Error = Bias + Variance + Noise

# %%
# Test Train Method :
# Take more time

# %% [markdown]
# # California Housing

# %%
import pandas as pd 
import numpy as np 
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.datasets import fetch_california_housing
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
# Load the dataset :
data = fetch_california_housing()
x = data.data
y = data.target

# %%
# Let's split the data into training and testing sets, fit the model and calculate the score

# %%
# Split the data into training and testing sets :
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
# Train / Validation split :
model = LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
# Valiation the model:
score_train_val = model.score(x_test,y_test)
print(f'Train / Valiation: {score_train_val}')
# Out:
# Train / Valiation: 0.5757877060324526

# %%
# Lets use cross-validation and calculate the score

# %%
# K-fold cross Validation:
scores_cv = cross_val_score(LinearRegression(), x,y,cv=10)

# %%
# Print each of the score and the average score :
print(f' Cross-Valiation score : {scores_cv}')
print(f' Average Cross-Valiation score : {np.mean(scores_cv)}')
# Out:
#  Cross-Valiation score : [0.48254494 0.61416063 0.42274892 0.48178521 0.55705986 0.5412919
#  0.47496038 0.45844938 0.48177943 0.59528796]
#  Average Cross-Valiation score : 0.5110068610523747

# %%
# Visualize score:
plt.figure(figsize=(12,6))
plt.bar(range(1,11) , scores_cv, color='cyan',label='Cross-Valiation score')
plt.axhline(y = score_train_val , color='red' , linestyle = '--', label='Train Valiation score')
plt.axhline(y = np.mean(scores_cv) , color='green' , linestyle = '--', label=' Average Cross-Valiation score ')
plt.xlabel('Fold Number')
plt.ylabel('Score')
plt.legend()
plt.title(' Comparison of Train / Valiation and Cross-Valiation score ')
plt.show()
